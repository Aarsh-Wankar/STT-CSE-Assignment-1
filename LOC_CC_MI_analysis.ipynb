# %%
import pandas as pd
df = pd.read_csv('final_df.csv')

# %%
df["Classes_Agree"].value_counts()
# Out:
# Classes_Agree
# YES    97
# NO     20
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
df["LOC_Change"].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of LOC_Change")
plt.xlabel("LOC Change")
plt.ylabel("Frequency")
plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
df["CC_Change"].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of CC_Change")
plt.xlabel("CC Change")
plt.ylabel("Frequency")
plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
df["MI_Change"].hist(bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of MI_Change")
plt.xlabel("MI Change")
plt.ylabel("Frequency")
plt.grid(False)
plt.show()
